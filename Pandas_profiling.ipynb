# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df.head()

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (2.1.4)
# Requirement already satisfied: matplotlib>=3.2.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (3.9.0)
# Requirement already satisfied: pydantic>=1.8.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (1.10.12)
# Requirement already satisfied: PyYAML>=5.0.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (3.1.3)
# Requirement already satisfied: markupsafe~=2.1.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (2.1.3)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (1.26.4)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.4-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (0.13.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Downloading multimethod-1.11.2-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: attrs>=19.3.0 in g:\apps install file\anaconda\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in g:\apps install file\anaconda\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: Pillow in g:\apps install file\anaconda\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in g:\apps install file\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in g:\apps install file\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in g:\apps install file\anaconda\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in g:\apps install file\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in g:\apps install file\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\apps install file\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in g:\apps install file\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.2.2)
# Requirement already satisfied: colorama in g:\apps install file\anaconda\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in g:\apps install file\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in g:\apps install file\anaconda\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.5.0)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#    ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/262.6 kB 1.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 30.7/262.6 kB 1.3 MB/s eta 0:00:01
#    ------ -------------------------------- 41.0/262.6 kB 326.8 kB/s eta 0:00:01
#    ----------------- -------------------- 122.9/262.6 kB 722.1 kB/s eta 0:00:01
#    ----------------------- -------------- 163.8/262.6 kB 821.4 kB/s eta 0:00:01
#    ----------------------------- -------- 204.8/262.6 kB 778.2 kB/s eta 0:00:01
#    -------------------------------------- 262.6/262.6 kB 849.6 kB/s eta 0:00:00
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    - -------------------------------------- 0.1/4.7 MB 3.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.3/4.7 MB 3.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.3/4.7 MB 2.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.5/4.7 MB 2.7 MB/s eta 0:00:02
#    ------ --------------------------------- 0.7/4.7 MB 3.3 MB/s eta 0:00:02
#    ------- -------------------------------- 0.9/4.7 MB 3.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.1/4.7 MB 3.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.4/4.7 MB 3.9 MB/s eta 0:00:01
#    ------------- -------------------------- 1.5/4.7 MB 4.1 MB/s eta 0:00:01
#    ------------- -------------------------- 1.6/4.7 MB 4.0 MB/s eta 0:00:01
#    --------------- ------------------------ 1.8/4.7 MB 3.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.9/4.7 MB 3.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.0/4.7 MB 3.5 MB/s eta 0:00:01
#    ------------------ --------------------- 2.2/4.7 MB 3.4 MB/s eta 0:00:01
#    ------------------- -------------------- 2.4/4.7 MB 3.3 MB/s eta 0:00:01
#    -------------------- ------------------- 2.5/4.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.6/4.7 MB 3.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.7/4.7 MB 3.1 MB/s eta 0:00:01
#    ------------------------ --------------- 2.9/4.7 MB 3.1 MB/s eta 0:00:01
#    ------------------------- -------------- 3.0/4.7 MB 3.1 MB/s eta 0:00:01
#    ------------------------- -------------- 3.1/4.7 MB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 3.2/4.7 MB 3.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.3/4.7 MB 3.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.4/4.7 MB 2.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.5/4.7 MB 2.9 MB/s eta 0:00:01
#    ------------------------------ --------- 3.7/4.7 MB 2.9 MB/s eta 0:00:01
#    ------------------------------- -------- 3.8/4.7 MB 2.9 MB/s eta 0:00:01
#    --------------------------------- ------ 3.9/4.7 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.0/4.7 MB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 4.3/4.7 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 4.5/4.7 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 4.6/4.7 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.7 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 2.7 MB/s eta 0:00:00
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    ---------------------------------------- 102.4/102.4 kB 3.0 MB/s eta 0:00:00
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#    ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#    ------------------------------ --------- 235.5/309.8 kB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 309.8/309.8 kB 3.8 MB/s eta 0:00:00
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-1.11.2-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp311-cp311-win_amd64.whl (667 kB)
#    ---------------------------------------- 0.0/667.1 kB ? eta -:--:--
#    ----------------- ---------------------- 297.0/667.1 kB 6.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 471.0/667.1 kB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  665.6/667.1 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 667.1/667.1 kB 4.2 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ---------------------------------------- 0.0/296.5 kB ? eta -:--:--
#    -------------------- ------------------- 153.6/296.5 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 296.5/296.5 kB 3.7 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27091 sha256=5759ff150bb18fd90f0ee20cd443f320250bff234df6dbc7d3e5c3fd89cf0156
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\8d\55\1a\19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: htmlmin, tangled-up-in-unicode, multimethod, joblib, imagehash, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 joblib-1.1.1 missingno-0.5.2 multimethod-1.11.2 pandas-profiling-3.2.0 phik-0.12.4 tangled-up-in-unicode-0.2.0 visions-0.7.4

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof=ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File G:\Apps install file\Anaconda\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File G:\Apps install file\Anaconda\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File G:\Apps install file\Anaconda\Lib\site-packages\pandas_profiling\profile_report.py:11
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\__init__.py:4
#       1 """Core functionality"""
#       3 from visions import types, typesets, utils
# ----> 4 from visions.backends import *
#       5 from visions.declarative import create_type
#       6 from visions.functional import (
#       7     cast_to_detected,
#       8     cast_to_inferred,
#       9     detect_type,
#      10     infer_type,
#      11 )
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\__init__.py:9
#       6 try:
#       7     import pandas as pd
# ----> 9     import visions.backends.pandas
#      10     from visions.backends.pandas.test_utils import pandas_version
#      12     if pandas_version[0] < 1:
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\pandas\__init__.py:2
#       1 import visions.backends.pandas.traversal
# ----> 2 import visions.backends.pandas.types
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\pandas\types\__init__.py:3
#       1 import visions.backends.pandas.types.boolean
#       2 import visions.backends.pandas.types.categorical
# ----> 3 import visions.backends.pandas.types.complex
#       4 import visions.backends.pandas.types.count
#       5 import visions.backends.pandas.types.date
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\pandas\types\complex.py:7
#       5 from visions.backends.pandas.series_utils import series_not_empty, series_not_sparse
#       6 from visions.backends.pandas.types.float import string_is_float
# ----> 7 from visions.backends.shared.parallelization_engines import pandas_apply
#       8 from visions.types.complex import Complex
#       9 from visions.types.string import String
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\shared\__init__.py:1
# ----> 1 from . import nan_handling, parallelization_engines, utilities
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\shared\nan_handling.py:34
#      30 # TODO: There are optimizations here, just have to define precisely the desired missing ruleset in the
#      31 # generated jit
#      32 if has_numba:
# ---> 34     @nb.generated_jit(nopython=True)
#      35     def is_missing(x):
#      36         """
#      37         Return True if the value is missing, False otherwise.
#      38         """
#      39         if isinstance(x, nb.types.Float):
#
# AttributeError: module 'numba' has no attribute 'generated_jit'

# %%
pip install --upgrade pandas-profiling visions numba
# Out:
# Requirement already satisfied: pandas-profiling in g:\apps install file\anaconda\lib\site-packages (3.2.0)
# Requirement already satisfied: visions in g:\apps install file\anaconda\lib\site-packages (0.7.4)
# Collecting visions
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numba in g:\apps install file\anaconda\lib\site-packages (0.59.0)
# Collecting numba
#   Downloading numba-0.59.1-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: joblib~=1.1.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (2.1.4)
# Requirement already satisfied: matplotlib>=3.2.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (3.9.0)
# Requirement already satisfied: pydantic>=1.8.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (1.10.12)
# Requirement already satisfied: PyYAML>=5.0.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (3.1.3)
# Requirement already satisfied: markupsafe~=2.1.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (2.1.3)
# Requirement already satisfied: numpy>=1.16.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (1.26.4)
# Requirement already satisfied: htmlmin>=0.1.12 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in g:\apps install file\anaconda\lib\site-packages (from pandas-profiling) (1.11.2)
# Requirement already satisfied: attrs>=19.3.0 in g:\apps install file\anaconda\lib\site-packages (from visions) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in g:\apps install file\anaconda\lib\site-packages (from visions) (3.1)
# Requirement already satisfied: imagehash in g:\apps install file\anaconda\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in g:\apps install file\anaconda\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.2.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in g:\apps install file\anaconda\lib\site-packages (from numba) (0.42.0)
# Requirement already satisfied: contourpy>=1.0.1 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in g:\apps install file\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in g:\apps install file\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in g:\apps install file\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in g:\apps install file\anaconda\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in g:\apps install file\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in g:\apps install file\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\apps install file\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in g:\apps install file\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.2.2)
# Requirement already satisfied: colorama in g:\apps install file\anaconda\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in g:\apps install file\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in g:\apps install file\anaconda\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.5.0)
# Downloading numba-0.59.1-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB 330.3 kB/s eta 0:00:08
#    - -------------------------------------- 0.1/2.6 MB 512.0 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/2.6 MB 654.9 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/2.6 MB 919.0 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.6 MB 983.9 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.4/2.6 MB 1.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.4/2.6 MB 1.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.4/2.6 MB 1.1 MB/s eta 0:00:03
#    -------- ------------------------------- 0.6/2.6 MB 1.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.7/2.6 MB 1.4 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.6 MB 1.5 MB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.6 MB 1.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.1/2.6 MB 1.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.2/2.6 MB 1.6 MB/s eta 0:00:01
#    -------------------- ------------------- 1.4/2.6 MB 1.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 1.9 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 2.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.0/2.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.6 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.6 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.6 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: numba
#   Attempting uninstall: numba
#     Found existing installation: numba 0.59.0
#     Uninstalling numba-0.59.0:
#       Successfully uninstalled numba-0.59.0
# Successfully installed numba-0.59.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'G:\Apps install file\Anaconda\Lib\site-packages\~umba'.
#   You can safely remove it manually.

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof=ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File G:\Apps install file\Anaconda\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File G:\Apps install file\Anaconda\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File G:\Apps install file\Anaconda\Lib\site-packages\pandas_profiling\profile_report.py:11
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\__init__.py:4
#       1 """Core functionality"""
#       3 from visions import types, typesets, utils
# ----> 4 from visions.backends import *
#       5 from visions.declarative import create_type
#       6 from visions.functional import (
#       7     cast_to_detected,
#       8     cast_to_inferred,
#       9     detect_type,
#      10     infer_type,
#      11 )
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\__init__.py:9
#       6 try:
#       7     import pandas as pd
# ----> 9     import visions.backends.pandas
#      10     from visions.backends.pandas.test_utils import pandas_version
#      12     if pandas_version[0] < 1:
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\pandas\__init__.py:2
#       1 import visions.backends.pandas.traversal
# ----> 2 import visions.backends.pandas.types
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\pandas\types\__init__.py:3
#       1 import visions.backends.pandas.types.boolean
#       2 import visions.backends.pandas.types.categorical
# ----> 3 import visions.backends.pandas.types.complex
#       4 import visions.backends.pandas.types.count
#       5 import visions.backends.pandas.types.date
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\pandas\types\complex.py:7
#       5 from visions.backends.pandas.series_utils import series_not_empty, series_not_sparse
#       6 from visions.backends.pandas.types.float import string_is_float
# ----> 7 from visions.backends.shared.parallelization_engines import pandas_apply
#       8 from visions.types.complex import Complex
#       9 from visions.types.string import String
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\shared\__init__.py:1
# ----> 1 from . import nan_handling, parallelization_engines, utilities
#
# File G:\Apps install file\Anaconda\Lib\site-packages\visions\backends\shared\nan_handling.py:34
#      30 # TODO: There are optimizations here, just have to define precisely the desired missing ruleset in the
#      31 # generated jit
#      32 if has_numba:
# ---> 34     @nb.generated_jit(nopython=True)
#      35     def is_missing(x):
#      36         """
#      37         Return True if the value is missing, False otherwise.
#      38         """
#      39         if isinstance(x, nb.types.Float):
#
# AttributeError: module 'numba' has no attribute 'generated_jit'

# %%
pip uninstall numba

# %%
df=pd.read_csv('train.csv')
df.head()
